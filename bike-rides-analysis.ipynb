# %%
#importing the necessary libraries

import pandas as pd

# %%
#here we are reading the csv file and puting in a pandas dataframe
data = pd.read_csv('/kaggle/input/london-bike-sharing-dataset/london_merged.csv')

# %%
#exploring the data a little bit
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
data.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
#counting unique values in the weather collumn
data.weather_code.value_counts()
# Out:
# weather_code
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: count, dtype: int64

# %%
#counting unique values in the season collumn
bikes.season.value_counts()
# Out:
# season
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: count, dtype: int64

# %%
#specifying better collumn names
new_cols_dict ={
    'timestamp':'time',
    'cnt':'count', 
    't1':'real_temperature_C',
    't2':'feels_like_temperature_C',
    'hum':'humidity_percent',
    'wind_speed':'wind_speed_kmh',
    'weather_code':'weather',
    'is_holiday':'is_holiday',
    'is_weekend':'is_weekend',
    'season':'season'
}

# Renaming the columns to the specified column names
data.rename(new_cols_dict, axis=1, inplace=True)

# %%
data.head()
# Out:
#                   time  count  real_temperature_C  feels_like_temperature_C  \
# 0  2015-01-04 00:00:00    182                 3.0                       2.0
# 1  2015-01-04 01:00:00    138                 3.0                       2.5
# 2  2015-01-04 02:00:00    134                 2.5                       2.5
# 3  2015-01-04 03:00:00     72                 2.0                       2.0
# 4  2015-01-04 04:00:00     47                 2.0                       0.0
#
#    humidity_percent  wind_speed_kmh  weather  is_holiday  is_weekend  season
# 0              93.0             6.0      3.0         0.0         1.0     3.0
# 1              93.0             5.0      1.0         0.0         1.0     3.0
# 2              96.5             0.0      1.0         0.0         1.0     3.0
# 3             100.0             0.0      1.0         0.0         1.0     3.0
# 4              93.0             6.5      1.0         0.0         1.0     3.0

# %%
#changing the humidity values to percentage (i.e. a value between 0 and 1)
data.humidity_percent = data.humidity_percent / 100

# %%
#creating a season dictionary so that we can map the integers 0-3 to the actual written values
season_dict = {
    '0.0':'spring',
    '1.0':'summer',
    '2.0':'autumn',
    '3.0':'winter'
}

#creating a weather dictionary so that we can map the integers to the actual written values
weather_dict = {
    '1.0':'Clear',
    '2.0':'Scattered clouds',
    '3.0':'Broken clouds',
    '4.0':'Cloudy',
    '7.0':'Rain',
    '10.0':'Rain with thunderstorm',
    '26.0':'Snowfall'
}

#changing the seasons column data type to string
data.season = data.season.astype('str')
#mapping the values 0-3 to the actual written seasons
data.season = data.season.map(season_dict)

# changing the weather column data type to string
data.weather = data.weather.astype('str')
# mapping the values to the actual written weathers
data.weather = data.weather.map(weather_dict)

# %%
data.head()
# Out:
#                   time  count  real_temperature_C  feels_like_temperature_C  \
# 0  2015-01-04 00:00:00    182                 3.0                       2.0
# 1  2015-01-04 01:00:00    138                 3.0                       2.5
# 2  2015-01-04 02:00:00    134                 2.5                       2.5
# 3  2015-01-04 03:00:00     72                 2.0                       2.0
# 4  2015-01-04 04:00:00     47                 2.0                       0.0
#
#    humidity_percent  wind_speed_kmh        weather  is_holiday  is_weekend  \
# 0             0.930             6.0  Broken clouds         0.0         1.0
# 1             0.930             5.0          Clear         0.0         1.0
# 2             0.965             0.0          Clear         0.0         1.0
# 3             1.000             0.0          Clear         0.0         1.0
# 4             0.930             6.5          Clear         0.0         1.0
#
#    season
# 0  winter
# 1  winter
# 2  winter
# 3  winter
# ...

# %%
#Adjusting the is_holiday collumn to a boolean form

#replacing 0 with False and 1 with True in the 'is_holiday' column
data['is_holiday'] = data['is_holiday'].replace({0: False, 1: True})

data.head()
# Out:
#                   time  count  real_temperature_C  feels_like_temperature_C  \
# 0  2015-01-04 00:00:00    182                 3.0                       2.0
# 1  2015-01-04 01:00:00    138                 3.0                       2.5
# 2  2015-01-04 02:00:00    134                 2.5                       2.5
# 3  2015-01-04 03:00:00     72                 2.0                       2.0
# 4  2015-01-04 04:00:00     47                 2.0                       0.0
#
#    humidity_percent  wind_speed_kmh        weather  is_holiday  is_weekend  \
# 0             0.930             6.0  Broken clouds       False         1.0
# 1             0.930             5.0          Clear       False         1.0
# 2             0.965             0.0          Clear       False         1.0
# 3             1.000             0.0          Clear       False         1.0
# 4             0.930             6.5          Clear       False         1.0
#
#    season
# 0  winter
# 1  winter
# 2  winter
# 3  winter
# ...

# %%
#Adjusting the is_weekend collumn to a boolean form

#replacing 0 with False and 1 with True in the 'is_holiday' column
data['is_weekend'] = data['is_weekend'].replace({0: False, 1: True})

data.head()
# Out:
#                   time  count  real_temperature_C  feels_like_temperature_C  \
# 0  2015-01-04 00:00:00    182                 3.0                       2.0
# 1  2015-01-04 01:00:00    138                 3.0                       2.5
# 2  2015-01-04 02:00:00    134                 2.5                       2.5
# 3  2015-01-04 03:00:00     72                 2.0                       2.0
# 4  2015-01-04 04:00:00     47                 2.0                       0.0
#
#    humidity_percent  wind_speed_kmh        weather  is_holiday  is_weekend  \
# 0             0.930             6.0  Broken clouds       False        True
# 1             0.930             5.0          Clear       False        True
# 2             0.965             0.0          Clear       False        True
# 3             1.000             0.0          Clear       False        True
# 4             0.930             6.5          Clear       False        True
#
#    season
# 0  winter
# 1  winter
# 2  winter
# 3  winter
# ...

# %%
data
# Out:
#                       time  count  real_temperature_C  \
# 0      2015-01-04 00:00:00    182                 3.0
# 1      2015-01-04 01:00:00    138                 3.0
# 2      2015-01-04 02:00:00    134                 2.5
# 3      2015-01-04 03:00:00     72                 2.0
# 4      2015-01-04 04:00:00     47                 2.0
# ...                    ...    ...                 ...
# 17409  2017-01-03 19:00:00   1042                 5.0
# 17410  2017-01-03 20:00:00    541                 5.0
# 17411  2017-01-03 21:00:00    337                 5.5
# 17412  2017-01-03 22:00:00    224                 5.5
# 17413  2017-01-03 23:00:00    139                 5.0
#
#        feels_like_temperature_C  humidity_percent  wind_speed_kmh  \
# 0                           2.0             0.930             6.0
# 1                           2.5             0.930             5.0
# 2                           2.5             0.965             0.0
# ...

# %%
# writing the final dataframe to an excel file 
data.to_excel('london_bikes_final.xlsx', sheet_name='Data')
